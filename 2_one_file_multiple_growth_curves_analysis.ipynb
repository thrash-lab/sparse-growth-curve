# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/thrash-lab/sparse-growth-curve/blob/main/2_one_file_multiple_growth_curves_analysis.ipynb)

# %% [markdown]
# ## This example is for analyzing the data in "input_file_example.xlsx"
# ## The output figures and tables will be stored in a newly created folder name "input_file_example"

# %%
#What is your file name?
# The input file has to be a '.xlsx' file
input_file='./input_file_example.xlsx'
input_file_name=input_file.split('.xlsx')[0]

# %%
import pandas as pd #pandas for reading tables
import numpy as np

from matplotlib import pyplot as plt
from matplotlib import cm
colormap=cm.tab10

import os
from datetime import datetime

from random import random

#statistical analysis
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression,RANSACRegressor
from scipy import stats

from scipy.interpolate import interp1d

# %% [markdown]
# # All the functions that are needed

# %%
def myLinearRegression_CB(x, y, x_fit, one_order=10):
  #print('\nFitting data:')
  #print('x = ', x)
  #print('y = ', y)

  corr=np.corrcoef(x,y)[0][1]
  #print('|corr|=', np.abs(corr))

  if (((np.abs(corr)<0.80) or (len(y)<4)) and 
      ((np.abs(corr)<0.90) or (len(y)<3)) and
      ((np.max(y)-np.min(y))<np.log2(one_order))):
    comp_y=np.median(y)*np.ones(len(y))
    pre_y=np.median(y)*np.ones(len(x_fit))
    doubling_rate=1e-6
  
  else:
    #Robust linear model estimation using RANSAC
    X=x.reshape(-1,1)
    if len(y)>4:
      try: 
        reg = RANSACRegressor()
        reg.fit(X, y)
        doubling_rate=reg.estimator_.coef_[0]
        inlier_mask = reg.inlier_mask_
        outlier_mask = np.logical_not(inlier_mask)
        
      except ValueError:
        #print('RANSAC could not find a valid consensus set.\n',
        #      'Running regular linear regression.')
        reg = LinearRegression()
        reg.fit(X,y)
        doubling_rate=reg.coef_[0]
    else:
        reg = LinearRegression()
        reg.fit(X,y)
        doubling_rate=reg.coef_[0]
    
    pre_y=reg.predict(x_fit.reshape(-1,1))
    comp_y=reg.predict(X)
  
  sigma=np.sqrt(
      np.sum(
          (comp_y-y)**2
          /
          (len(x)-1))
      )

  T_95 = stats.t.ppf(0.95, len(x)-1)

  G=np.sqrt(
      1/len(x)
      +
      (x_fit-np.mean(x))**2
      /
      sum((x-np.mean(x))**2)
      )

  ci=sigma*T_95*G
  
  #sigma**2/np.sum()

  return (doubling_rate, pre_y, ci)

# %%
def preprocessing_growth_curve(time, cell_density):
  t=np.array(time)
  X=np.array(cell_density)

  #for i in range(len(time)-3):
  #  t=np.r_[t,np.median(time[[i,i+1,i+2]])]
  #  X=np.r_[X, np.median(cell_density[[i,i+1, i+2]])]

  X=X[np.argsort(t)]
  t=t[np.argsort(t)]

  #You might get multiple cell counts for the same sample at one time.
  #Here, I merge the cell densities by their mean:
  #using the function "np.unique"
  #I get rid of the duplicated time points
  t1=np.unique(t) 
  X1=[]
  for tt in t1:
    temporary_cell_densities=X[t==tt]
    #Getting the mean cell density at a time point
    X1.append(np.median(temporary_cell_densities))
  X1=np.array(X1)

  return t1, X1

# %%
def phase_seperations(t, X, max_depth=1):

  gamma=np.diff(np.log2(X))/np.diff(t)
  gamma=np.r_[gamma, gamma, gamma]
  #gamma=np.r_[gamma[0], gamma]
  t_gamma=np.r_[t[0:-1],
                np.array([(t[i]+t[i+1])/2 for i in range(len(t)-1)]),
                t[1::]]

  gamma_2=np.diff(np.log2(X)[::2])/np.diff(t[::2])
  gamma_2=np.r_[gamma_2, gamma_2, gamma_2]
  t_gamma_2=np.r_[t[::2][0:-1],
                  [(t[::2][i]+t[::2][i+1])/2 for i in range(len(t[::2])-1)],
                  t[::2][1::]]


  gamma_3=np.diff(np.log2(X)[::3])/np.diff(t[::3])
  gamma_3=np.r_[gamma_3, gamma_3, gamma_3]
  t_gamma_3=np.r_[t[::3][0:-1],
                  [(t[::3][i]+t[::3][i+1])/2 for i in range(len(t[::3])-1)],
                  t[::3][1::]]

  all_t_gamma=np.r_[t_gamma,t_gamma_2, t_gamma_3]
  all_gamma=np.r_[gamma, gamma_2, gamma_3]

  all_gamma=all_gamma[np.argsort(all_t_gamma)]
  all_t_gamma=np.sort(all_t_gamma)

  all_gamma=np.array([np.median(all_gamma[[i,i+1,i+2,i+3,
                                          i+4,i+5,i+6,i+7,i+8]]) 
                      for i in range(len(all_t_gamma)-9)])
  all_t_gamma=np.array([np.median(all_t_gamma[[i,i+1,i+2,i+3,
                                              i+4,i+5,i+6,i+7,i+8]]) 
                      for i in range(len(all_t_gamma)-9)])

  sel_t_gamma=np.unique(all_t_gamma)
  sel_gamma=[]
  for stg in sel_t_gamma:
    sel_gamma.append(
        np.mean(all_gamma[all_t_gamma==stg]))
  sel_gamma=np.array(sel_gamma)

  # By default, max_depth = 1
  # Because for a standard growth curve (no diauxic shift) without death phase,
  # there would only be two states:
  # 1. Not growing (lag phase and stationary), growth rate is close to 0;
  # 2. Growing exponentially at an almost constant rate.

  regr_1 = DecisionTreeRegressor(max_depth=max_depth)
  regr_1.fit(all_t_gamma.reshape(-1, 1), all_gamma)

  t_fit = np.arange(0.0, t[-1], 0.01)[:, np.newaxis]
  gamma_fit = regr_1.predict(t_fit)

  #We find the state transition point
  gamma_fit_diff=np.diff(gamma_fit)
  inflection_points=t_fit[1::][gamma_fit_diff!=0]

  all_starting_time=np.r_[[0],inflection_points.reshape(1,-1)[0], t_fit[-1]]

  return all_starting_time

# %%
def phases_exponential_fit(phases_points, t, X, one_order):
  all_starting_time=phases_points

  all_doubling_rates=[]
  all_fit_time=[]
  all_fit_cell_density=[]
  all_fit_conf_band=[]

  print('All phases points', all_starting_time)
  t_1 = np.arange(0.0, t[-1], 0.01)[:, np.newaxis]
  for i in range(len(all_starting_time)-1):
    start_t=all_starting_time[i]
    end_t=all_starting_time[i+1]

    #print('Time period: ', start_t, 'hours  ---', end_t, 'hours')
    # Chooseing the time period:
    sel_bool=(t>=start_t-1) & (t<=end_t+1)
    #if np.sum(sel_bool)<3:
    #  if np.where(sel_bool)[0][0]!=0 and np.where(sel_bool)[0][-1]!=len(sel_bool)-1:
    #    sel_bool[np.where(sel_bool)[0][0]-1]=True
    #    sel_bool[np.where(sel_bool)[0][-1]+1]=True
    #  elif np.where(sel_bool)[0][0]!=0:
    #    sel_bool[np.where(sel_bool)[0][0]-1]=True
    #  elif np.where(sel_bool)[0][-1]!=len(sel_bool)-1:
    #    sel_bool[np.where(sel_bool)[0][-1]+1]=True

    if np.sum(sel_bool)>=2:
      sel_t=t[sel_bool]
      sel_X=X[sel_bool]

      #print(sel_t, sel_X)

      fit_bool=(t_1>=start_t-1) & (t_1<=end_t+1)
      sel_t_1=t_1[fit_bool]

      (dr, pre_X_1, ci)=myLinearRegression_CB(
          sel_t, 
          np.log2(sel_X), 
          sel_t_1)
      
      all_doubling_rates.append(dr)
      all_fit_time.append(sel_t_1)
      all_fit_cell_density.append(2**pre_X_1)
      all_fit_conf_band.append(2**ci)

      print('Doubling rate:', dr, 'doubling/hour')
      print('\n')

    else:
      print('No data point in this time period, not fitting.')

  return (all_doubling_rates,
            all_fit_time,
            all_fit_cell_density,
            all_fit_conf_band)

# %%
def growth_death_rate_decision(all_fit_cell_density,
                               all_fit_time,
                               all_doubling_rates):
  #all_starting_time=phases_points
  all_acrossing_orders=[]
  for i in range(len(all_fit_cell_density)):
    start_t=all_fit_time[i][0]
    end_t=all_fit_time[i][-1]

    print('\nTime period: ', start_t, 'hours  ---', end_t, 'hours')

    afc = all_fit_cell_density[i]
    acrossing_orders=np.log10(afc[-1])-np.log10(afc[0])
    all_acrossing_orders.append(acrossing_orders)
    
    print('Doubling rate:', all_doubling_rates[i], 'doubling/hour')
    print('Number of orders acrossing:', acrossing_orders)

  selected_doubling_rate=0
  selected_fit_time=0
  selected_fit_cell_density=all_fit_cell_density[0][0]

  selected_doubling_rate_d=0
  selected_fit_time_d=all_fit_time[-1][-1]
  selected_fit_cell_density_d=all_fit_cell_density[-1][-1]

  #Growth phase:
  if max(all_acrossing_orders)>0:
    selected_i=np.argmax(all_acrossing_orders)
    selected_doubling_rate=all_doubling_rates[selected_i]
    selected_fit_time=all_fit_time[selected_i]
    selected_fit_cell_density=all_fit_cell_density[selected_i]

  #Death phase:
  if min(all_acrossing_orders)<0:
    selected_i_d=np.argmin(all_acrossing_orders)
    selected_doubling_rate_d=all_doubling_rates[selected_i_d]
    selected_fit_time_d=all_fit_time[selected_i_d]
    selected_fit_cell_density_d=all_fit_cell_density[selected_i_d]

  return (selected_doubling_rate,
          selected_fit_time,
          selected_fit_cell_density,
          selected_doubling_rate_d,
          selected_fit_time_d,
          selected_fit_cell_density_d)

# %%
def fit_growth_curve(time, cell_density, one_order=10, decision_tree_depth=1):
  t1,X1=preprocessing_growth_curve(time, cell_density)
  phases_points=phase_seperations(t1, X1, max_depth=decision_tree_depth)

  print(phases_points)
  
  (all_doubling_rates,
            all_fit_time,
            all_fit_cell_density,
            all_fit_conf_band)=phases_exponential_fit(phases_points, t1, X1, 
                                                 one_order)

  (selected_doubling_rate,
          selected_fit_time,
          selected_fit_cell_density,
          selected_doubling_rate_d,
          selected_fit_time_d,
          selected_fit_cell_density_d)=growth_death_rate_decision(
                               all_fit_cell_density,
                               all_fit_time,
                               all_doubling_rates)
          
  return (all_fit_time,
          all_fit_cell_density,
          all_fit_conf_band,
          selected_doubling_rate,
          selected_fit_time,
          selected_fit_cell_density,
          selected_doubling_rate_d,
          selected_fit_time_d,
          selected_fit_cell_density_d)

# %% [markdown]
# # Importing the file

# %%
# datetime object containing current date and time
now = datetime.now()
 
#print("now =", now)

dt_string = now.strftime("%Y-%m-%d-%H_%M_%S")
print('Creating a time stamp:')
print("YYYY-MM-DD-hh_mm_ss =", dt_string)

output_folder=input_file.split('.xlsx')[0]+'/'

print('I received your input data from:  '+input_file)
print('The output will be stored in the folder called:  '+output_folder+'\n.\n.\n.')

if os.path.exists(output_folder)==False:
    os.mkdir(output_folder)
# Out:
# Creating a time stamp:
# YYYY-MM-DD-hh_mm_ss = 2021-02-10-20_12_00
# I received your input data from:  ./input_file_example.xlsx
# The output will be stored in the folder called:  ./input_file_example/
# .
# .
# .

# %%
#Read the data
df=pd.read_excel(
    input_file, sheet_name='Data').fillna(method='ffill')

df.columns=df.columns.str.strip()
file_data_frame=df[['Strain', 'Replicate', 'Cell density', 'Time', 'Condition']]

file_data_units=pd.read_excel(input_file, sheet_name='Units', index_col=0).fillna(' ')

print('Here is how the growth curves data looks like:')
print(file_data_frame)
print('\n.\n.\n.')
# Out:
# Here is how the growth curves data looks like:
#         Strain  Replicate  Cell density  Time  Condition
# 0    LSUCC0684          1          5100     0          4
# 1    LSUCC0684          2          4370     0          4
# 2    LSUCC0684          3          4470     0          4
# 3    LSUCC0719          1          7050     0          4
# 4    LSUCC0719          2         15400     0          4
# ..         ...        ...           ...   ...        ...
# 716  LSUCC0744          2       2790000   354         12
# 717  LSUCC0744          3       1840000   354         12
# 718  LSUCC0744          1       1450000   378         12
# 719  LSUCC0744          2       3310000   378         12
# 720  LSUCC0744          3       2470000   378         12
#
# [721 rows x 5 columns]
#
# .
# .
# .

# %%
print('Here are the units for the columns:')
print(file_data_units)
print('\n.\n.\n.')

condition_unit=file_data_units.loc['Condition'].values[0]
time_unit=str(file_data_units.loc['Time'].values[0])
cell_density_unit=str(file_data_units.loc['Cell density'].values[0])
# Out:
# Here are the units for the columns:
#                      Unit
# Column
# Strain
# Replicate
# Cell density     cells/mL
# Time                    h
# Condition     $\degree$ C
#
# .
# .
# .

# %% [markdown]
# # Fit the data and get growth/death rates.

# %%
output_data_indices=file_data_frame.groupby(
    ['Strain','Replicate','Condition']
    ).size().reset_index().rename(columns={0:'count'}
                                  )[['Strain','Replicate','Condition']]

strains_conditions=output_data_indices.groupby(['Strain','Condition']
                            ).size().reset_index()[['Strain','Condition']]

output_data_indices['Growth: Doubling rate']=0
output_data_indices['Death: Doubling rate']=0

output_data_indices=output_data_indices.astype(object)
output_data_indices=output_data_indices.sort_values(by=['Strain','Condition'])

strains=np.unique(strains_conditions['Strain'])
row_num=len(strains)
col_num=np.int(np.ceil(len(strains_conditions)/len(strains)))

# %matplotlib inline
plt.figure(figsize=(col_num*2+1,
                    row_num*2+1))

plot_j=1
previous_condition=output_data_indices['Condition'].values[0]
plt.subplot(row_num, col_num, plot_j)
color_i=0
plt.title(str(output_data_indices['Strain'].values[0])+'\n'
          +str(output_data_indices['Condition'].values[0])+' '
          +condition_unit)
plt.ylabel(cell_density_unit)
plt.xlabel(time_unit)

for i in output_data_indices.index:
  target_gr_index=output_data_indices.loc[i]

  target_growth_curve_df = file_data_frame[
  (file_data_frame['Strain']==target_gr_index['Strain'])&
  (file_data_frame['Condition']==target_gr_index['Condition']) &
  (file_data_frame['Replicate']==target_gr_index['Replicate'])]

  #print('\n\nStrain:', target_gr_index['Strain'], 
  #      '\t Condition:',str(target_gr_index['Condition'])+' '+condition_unit,
  #      '\t Replicate:',str(target_gr_index['Replicate']))

  time=target_growth_curve_df.loc[:,'Time'].values
  cell_density=target_growth_curve_df.loc[:,'Cell density'].values

  #print('time=', time)
  #print('cell density=', 'cell_density')

  if target_gr_index['Condition']!=previous_condition:
    plt.yscale('log')
    plt.ylim(10**np.floor(np.log10(np.min(file_data_frame['Cell density']))-1),
             10**np.ceil(np.log10(np.max(file_data_frame['Cell density']))+1))
    
    plt.legend()
    #plt.xlim(np.floor(np.min(file_data_frame['Time'])),
    #         np.ceil(np.max(file_data_frame['Time'])))
    color_i=0
    plot_j+=1
    plt.subplot(row_num, col_num, plot_j)
    plt.title(str(target_gr_index['Strain'])+'\n'
              +str(target_gr_index['Condition'])+' '
              +condition_unit)
    
    plt.ylabel(cell_density_unit)
    plt.xlabel(time_unit)

  if len(cell_density)>4:
    (all_fit_time,
            all_fit_cell_density,
            all_fit_conf_band,
            selected_doubling_rate,
            selected_fit_time,
            selected_fit_cell_density,
            selected_doubling_rate_d,
            selected_fit_time_d,
            selected_fit_cell_density_d)=fit_growth_curve(
                time, cell_density, one_order=2, decision_tree_depth=1)
    output_data_indices.loc[i,'Growth: Doubling rate']=selected_doubling_rate
    output_data_indices.loc[i,'Death: Doubling rate']=selected_doubling_rate_d

    for k in range(len(all_fit_time)):
        #plt.plot(all_fit_time[i], all_fit_cell_density[i], 'k--')
        #plt.fill_between(all_fit_time[k], 
        #                all_fit_cell_density[k]*(all_fit_conf_band[k]),
        #                all_fit_cell_density[k]/(all_fit_conf_band[k]),
        #                color=colormap(color_i), alpha=0.1)
        plt.plot(selected_fit_time, selected_fit_cell_density, '-', 
                color=colormap(color_i), linewidth=2)
        
        plt.plot(selected_fit_time_d, selected_fit_cell_density_d, '--', 
                color=colormap(color_i), linewidth=1)  

  elif len(cell_density)>2:
    x=time
    y=np.log2(cell_density)
    x_fit = np.arange(0.0, x[-1], 0.01)[:, np.newaxis]
    (doubling_rate, pre_y, ci) = myLinearRegression_CB(x, y, x_fit, one_order=10)

    #plt.fill_between(x_fit, 
    #                pre_y*ci,
    #                pre_y/ci,
    #                color=colormap(color_i), alpha=0.1)
        
    if doubling_rate>0:
      output_data_indices.loc[i,'Growth: Doubling rate']=doubling_rate
      plt.plot(x_fit, pre_y, '-', color=colormap(color_i), linewidth=2)
    else:
      output_data_indices.loc[i,'Death: Doubling rate']=doubling_rate
      plt.plot(x_fit, pre_y, '--', color=colormap(color_i), linewidth=1)

  elif len(cell_density)==2:
    x=time
    y=np.log2(cell_density)
    doubling_rate=(y[1]-y[0])/(x[1]-x[0])
    output_data_indices.loc[i,'Growth: Doubling rate']=doubling_rate
    if doubling_rate>0:
      output_data_indices.loc[i,'Growth: Doubling rate']=doubling_rate
      plt.plot(x, y, '-', color=colormap(color_i), linewidth=2)
    else:
      output_data_indices.loc[i,'Death: Doubling rate']=doubling_rate
      plt.plot(x, y, '--', color=colormap(color_i), linewidth=1)     

  plt.plot(time, cell_density,'o',alpha=0.3, color=colormap(color_i),
          label=output_data_indices.loc[i]['Replicate'])
  color_i+=1
  previous_condition=output_data_indices.loc[i]['Condition']

plt.yscale('log')
plt.ylim(10**np.floor(np.log10(np.min(file_data_frame['Cell density']))-1),
         10**np.ceil(np.log10(np.max(file_data_frame['Cell density']))+1))

#plt.xlim(np.floor(np.min(file_data_frame['Time'])),
#         np.ceil(np.max(file_data_frame['Time'])))
plt.legend()
    
plt.tight_layout()
output_file_string=output_folder+'1_Data_fit_visualization_'+dt_string+'.pdf'
plt.savefig(output_file_string)

print('output file saved:'+output_file_string)
plt.show()
# Out:
# [  0.   221.01 353.99]
# All phases points [  0.   221.01 353.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 222.01 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  220.01 hours  --- 353.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.   167.01 353.99]
# All phases points [  0.   167.01 353.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 168.01 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  166.01 hours  --- 353.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    93.26 353.99]
# All phases points [  0.    93.26 353.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 94.26 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  92.26 hours  --- 353.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    45.01 353.99]
# All phases points [  0.    45.01 353.99]
# Doubling rate: 0.016919208584975882 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 46.01 hours
# Doubling rate: 0.016919208584975882 doubling/hour
# Number of orders acrossing: 0.2343376390936407
#
# Time period:  44.01 hours  --- 353.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.   305.51 353.99]
# All phases points [  0.   305.51 353.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 306.51 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  304.51 hours  --- 353.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.   287.26 353.99]
# All phases points [  0.   287.26 353.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 288.26 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  286.26 hours  --- 353.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.   203.01 305.99]
# All phases points [  0.   203.01 305.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 204.01 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  202.01 hours  --- 305.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.   179.01 305.99]
# All phases points [  0.   179.01 305.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 180.01 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  178.01 hours  --- 305.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.   228.51 305.99]
# All phases points [  0.   228.51 305.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 229.51 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  227.51 hours  --- 305.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.   179.01 256.99]
# All phases points [  0.   179.01 256.99]
# Doubling rate: 0.05139313868427551 doubling/hour
#
#
# Doubling rate: 0.010468824806075408 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 180.01 hours
# Doubling rate: 0.05139313868427551 doubling/hour
# Number of orders acrossing: 2.7849124455146033
#
# Time period:  178.01 hours  --- 256.99 hours
# Doubling rate: 0.010468824806075408 doubling/hour
# Number of orders acrossing: 0.24889996398669023
# [  0.   167.01 256.99]
# All phases points [  0.   167.01 256.99]
# Doubling rate: 0.058051853226465396 doubling/hour
#
#
# Doubling rate: 0.004562681567695113 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 168.01 hours
# Doubling rate: 0.058051853226465396 doubling/hour
# Number of orders acrossing: 2.936033406499474
#
# Time period:  166.01 hours  --- 256.99 hours
# Doubling rate: 0.004562681567695113 doubling/hour
# Number of orders acrossing: 0.12496139506083281
# [  0.   155.01 256.99]
# All phases points [  0.   155.01 256.99]
# Doubling rate: 0.06441475675435862 doubling/hour
#
#
# Doubling rate: 0.010038937661605237 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 156.01 hours
# Doubling rate: 0.06441475675435862 doubling/hour
# Number of orders acrossing: 3.025154643387376
#
# Time period:  154.01 hours  --- 256.99 hours
# Doubling rate: 0.010038937661605237 doubling/hour
# Number of orders acrossing: 0.3112077597294185
# [  0.    69.01 136.99]
# All phases points [  0.    69.01 136.99]
# Doubling rate: 0.15191706500565916 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 70.01 hours
# Doubling rate: 0.15191706500565916 doubling/hour
# Number of orders acrossing: 3.2016688553298827
#
# Time period:  68.01 hours  --- 136.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    69.01 136.99]
# All phases points [  0.    69.01 136.99]
# Doubling rate: 0.16035349435073637 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 70.01 hours
# Doubling rate: 0.16035349435073637 doubling/hour
# Number of orders acrossing: 3.3794675317545395
#
# Time period:  68.01 hours  --- 136.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    69.01 136.99]
# All phases points [  0.    69.01 136.99]
# Doubling rate: 0.15218251562147833 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 70.01 hours
# Doubling rate: 0.15218251562147833 doubling/hour
# Number of orders acrossing: 3.2072632562568937
#
# Time period:  68.01 hours  --- 136.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    69.01 136.99]
# All phases points [  0.    69.01 136.99]
# Doubling rate: 0.1556260239892717 doubling/hour
#
#
# Doubling rate: -0.005329587110943307 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 70.01 hours
# Doubling rate: 0.1556260239892717 doubling/hour
# Number of orders acrossing: 3.2798355738817824
#
# Time period:  68.01 hours  --- 136.99 hours
# Doubling rate: -0.005329587110943307 doubling/hour
# Number of orders acrossing: -0.11066913804626832
# [  0.    57.01 136.99]
# All phases points [  0.    57.01 136.99]
# Doubling rate: 0.18197962461627382 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 58.01 hours
# Doubling rate: 0.18197962461627382 doubling/hour
# Number of orders acrossing: 3.177864698587942
#
# Time period:  56.01 hours  --- 136.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    81.01 136.99]
# All phases points [  0.    81.01 136.99]
# Doubling rate: 0.13348479860613935 doubling/hour
#
#
# Doubling rate: -0.004577305317102968 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 82.01 hours
# Doubling rate: 0.13348479860613935 doubling/hour
# Number of orders acrossing: 3.2954019536237658
#
# Time period:  80.01 hours  --- 136.99 hours
# Doubling rate: -0.004577305317102968 doubling/hour
# Number of orders acrossing: -0.07851309526233763
# [  0.   130.76 208.99]
# All phases points [  0.   130.76 208.99]
# Doubling rate: -0.009747628014085826 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 131.76 hours
# Doubling rate: -0.009747628014085826 doubling/hour
# Number of orders acrossing: -0.38662711246297965
#
# Time period:  129.76 hours  --- 208.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    93.26 208.99]
# All phases points [  0.    93.26 208.99]
# Doubling rate: -0.015884386785852647 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 94.26 hours
# Doubling rate: -0.015884386785852647 doubling/hour
# Number of orders acrossing: -0.4507208632055715
#
# Time period:  92.26 hours  --- 208.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.   130.76 208.99]
# All phases points [  0.   130.76 208.99]
# Doubling rate: -0.015601360777948001 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 131.76 hours
# Doubling rate: -0.015601360777948001 doubling/hour
# Number of orders acrossing: -0.6188078842724405
#
# Time period:  129.76 hours  --- 208.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    45.01 353.99]
# All phases points [  0.    45.01 353.99]
# Doubling rate: 0.03293464768657668 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 46.01 hours
# Doubling rate: 0.03293464768657668 doubling/hour
# Number of orders acrossing: 0.4561577182816099
#
# Time period:  44.01 hours  --- 353.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.   118.26 353.99]
# All phases points [  0.   118.26 353.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: 0.002193730164348088 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 119.26 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  117.26 hours  --- 353.99 hours
# Doubling rate: 0.002193730164348088 doubling/hour
# Number of orders acrossing: 0.15633142168410785
# [  0.    69.01 353.99]
# All phases points [  0.    69.01 353.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 70.01 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  68.01 hours  --- 353.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    69.01 353.99]
# All phases points [  0.    69.01 353.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 70.01 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  68.01 hours  --- 353.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    57.01 353.99]
# All phases points [  0.    57.01 353.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: 0.002189560359606615 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 58.01 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  56.01 hours  --- 353.99 hours
# Doubling rate: 0.002189560359606615 doubling/hour
# Number of orders acrossing: 0.1964055745094928
# [  0.    29.26 353.99]
# All phases points [  0.    29.26 353.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: 0.001737664849386811 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 30.26 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  28.26 hours  --- 353.99 hours
# Doubling rate: 0.001737664849386811 doubling/hour
# Number of orders acrossing: 0.17038585882153345
# [  0.   203.01 305.99]
# All phases points [  0.   203.01 305.99]
# Doubling rate: 0.031118154383842626 doubling/hour
#
#
# Doubling rate: 0.01787374035581935 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 204.01 hours
# Doubling rate: 0.031118154383842626 doubling/hour
# Number of orders acrossing: 1.911063242343598
#
# Time period:  202.01 hours  --- 305.99 hours
# Doubling rate: 0.01787374035581935 doubling/hour
# Number of orders acrossing: 0.5594677154687524
# [  0.   203.01 305.99]
# All phases points [  0.   203.01 305.99]
# Doubling rate: 0.030302527042559535 doubling/hour
#
#
# Doubling rate: 0.01922456898959727 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 204.01 hours
# Doubling rate: 0.030302527042559535 doubling/hour
# Number of orders acrossing: 1.8609730148786339
#
# Time period:  202.01 hours  --- 305.99 hours
# Doubling rate: 0.01922456898959727 doubling/hour
# Number of orders acrossing: 0.6017501361979667
# [  0.   209.51 305.99]
# All phases points [  0.   209.51 305.99]
# Doubling rate: 0.0315033789514943 doubling/hour
#
#
# Doubling rate: 0.016166538054072532 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 210.51 hours
# Doubling rate: 0.0315033789514943 doubling/hour
# Number of orders acrossing: 1.9963635917603835
#
# Time period:  208.51 hours  --- 305.99 hours
# Doubling rate: 0.016166538054072532 doubling/hour
# Number of orders acrossing: 0.4743974235734987
# [  0.   118.26 256.99]
# All phases points [  0.   118.26 256.99]
# Doubling rate: 0.04838191902755132 doubling/hour
#
#
# Doubling rate: 0.01086015871549044 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 119.26 hours
# Doubling rate: 0.04838191902755132 doubling/hour
# Number of orders acrossing: 1.736951402441905
#
# Time period:  117.26 hours  --- 256.99 hours
# Doubling rate: 0.01086015871549044 doubling/hour
# Number of orders acrossing: 0.4568100012914149
# [  0.   130.76 256.99]
# All phases points [  0.   130.76 256.99]
# Doubling rate: 0.06785049624922247 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 131.76 hours
# Doubling rate: 0.06785049624922247 doubling/hour
# Number of orders acrossing: 2.6912025578027094
#
# Time period:  129.76 hours  --- 256.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.   130.76 256.99]
# All phases points [  0.   130.76 256.99]
# Doubling rate: 0.06792894036277682 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 131.76 hours
# Doubling rate: 0.06792894036277682 doubling/hour
# Number of orders acrossing: 2.6943139425487637
#
# Time period:  129.76 hours  --- 256.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    81.01 136.99]
# All phases points [  0.    81.01 136.99]
# Doubling rate: 0.07402749405054633 doubling/hour
#
#
# Doubling rate: 0.025540929924130394 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 82.01 hours
# Doubling rate: 0.07402749405054633 doubling/hour
# Number of orders acrossing: 1.8275515344323416
#
# Time period:  80.01 hours  --- 136.99 hours
# Doubling rate: 0.025540929924130394 doubling/hour
# Number of orders acrossing: 0.43809563166546983
# [  0.    81.01 136.99]
# All phases points [  0.    81.01 136.99]
# Doubling rate: 0.10943457224219512 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 82.01 hours
# Doubling rate: 0.10943457224219512 doubling/hour
# Number of orders acrossing: 2.701662713107801
#
# Time period:  80.01 hours  --- 136.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    81.01 136.99]
# All phases points [  0.    81.01 136.99]
# Doubling rate: 0.10637122998073274 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 82.01 hours
# Doubling rate: 0.10637122998073274 doubling/hour
# Number of orders acrossing: 2.626036543098529
#
# Time period:  80.01 hours  --- 136.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    57.01 208.99]
# All phases points [  0.    57.01 208.99]
# Doubling rate: 0.01811246106218712 doubling/hour
#
#
# Doubling rate: -0.004109491946005203 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 58.01 hours
# Doubling rate: 0.01811246106218712 doubling/hour
# Number of orders acrossing: 0.31629338029157505
#
# Time period:  56.01 hours  --- 208.99 hours
# Doubling rate: -0.004109491946005203 doubling/hour
# Number of orders acrossing: -0.18924855082427428
# [  0.    45.01 208.99]
# All phases points [  0.    45.01 208.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: -0.005900001593371671 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 46.01 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  44.01 hours  --- 208.99 hours
# Doubling rate: -0.005900001593371671 doubling/hour
# Number of orders acrossing: -0.2930172583724939
# [  0.    45.01 208.99]
# All phases points [  0.    45.01 208.99]
# Doubling rate: 0.030558101712365372 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 46.01 hours
# Doubling rate: 0.030558101712365372 doubling/hour
# Number of orders acrossing: 0.42324162944701094
#
# Time period:  44.01 hours  --- 208.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    81.01 208.99]
# All phases points [  0.    81.01 208.99]
# Doubling rate: -0.00690688497396412 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 82.01 hours
# Doubling rate: -0.00690688497396412 doubling/hour
# Number of orders acrossing: -0.17051351520418923
#
# Time period:  80.01 hours  --- 208.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    69.01 208.99]
# All phases points [  0.    69.01 208.99]
# Doubling rate: -0.007846030044659424 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 70.01 hours
# Doubling rate: -0.007846030044659424 doubling/hour
# Number of orders acrossing: -0.1653559462265335
#
# Time period:  68.01 hours  --- 208.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    81.01 208.99]
# All phases points [  0.    81.01 208.99]
# Doubling rate: -0.00792194973376339 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 82.01 hours
# Doubling rate: -0.00792194973376339 doubling/hour
# Number of orders acrossing: -0.19557289595335625
#
# Time period:  80.01 hours  --- 208.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    69.01 353.99]
# All phases points [  0.    69.01 353.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 70.01 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  68.01 hours  --- 353.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    57.01 353.99]
# All phases points [  0.    57.01 353.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 58.01 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  56.01 hours  --- 353.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    45.01 353.99]
# All phases points [  0.    45.01 353.99]
# Doubling rate: 0.017771610635585824 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 46.01 hours
# Doubling rate: 0.017771610635585824 doubling/hour
# Number of orders acrossing: 0.24614374001705475
#
# Time period:  44.01 hours  --- 353.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.   130.76 377.99]
# All phases points [  0.   130.76 377.99]
# Doubling rate: 0.005041661353542453 doubling/hour
#
#
# Doubling rate: 0.022194394821552978 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 131.76 hours
# Doubling rate: 0.005041661353542453 doubling/hour
# Number of orders acrossing: 0.1999710050813963
#
# Time period:  129.76 hours  --- 377.99 hours
# Doubling rate: 0.022194394821552978 doubling/hour
# Number of orders acrossing: 1.6584689581430867
# [  0.   130.76 377.99]
# All phases points [  0.   130.76 377.99]
# Doubling rate: 0.009167457872874466 doubling/hour
#
#
# Doubling rate: 0.025178842797021588 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 131.76 hours
# Doubling rate: 0.009167457872874466 doubling/hour
# Number of orders acrossing: 0.3636154109382961
#
# Time period:  129.76 hours  --- 377.99 hours
# Doubling rate: 0.025178842797021588 doubling/hour
# Number of orders acrossing: 1.8814808656225885
# [  0.   130.76 377.99]
# All phases points [  0.   130.76 377.99]
# Doubling rate: 0.007424633693221622 doubling/hour
#
#
# Doubling rate: 0.024971910768470173 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 131.76 hours
# Doubling rate: 0.007424633693221622 doubling/hour
# Number of orders acrossing: 0.29448853421134924
#
# Time period:  129.76 hours  --- 377.99 hours
# Doubling rate: 0.024971910768470173 doubling/hour
# Number of orders acrossing: 1.8660179368715495
# [  0.   203.01 305.99]
# All phases points [  0.   203.01 305.99]
# Doubling rate: 0.03819429117162466 doubling/hour
#
#
# Doubling rate: 0.006638829233598602 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 204.01 hours
# Doubling rate: 0.03819429117162466 doubling/hour
# Number of orders acrossing: 2.3456309466527916
#
# Time period:  202.01 hours  --- 305.99 hours
# Doubling rate: 0.006638829233598602 doubling/hour
# Number of orders acrossing: 0.20780265074731918
# [  0.   191.01 305.99]
# All phases points [  0.   191.01 305.99]
# Doubling rate: 0.04299800505251458 doubling/hour
#
#
# Doubling rate: 0.006294905179441485 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 192.01 hours
# Doubling rate: 0.04299800505251458 doubling/hour
# Number of orders acrossing: 2.48531777760026
#
# Time period:  190.01 hours  --- 305.99 hours
# Doubling rate: 0.006294905179441485 doubling/hour
# Number of orders acrossing: 0.21977691324362603
# [  0.   203.01 305.99]
# All phases points [  0.   203.01 305.99]
# Doubling rate: 0.04262446393859961 doubling/hour
#
#
# Doubling rate: 0.004254555932790008 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 204.01 hours
# Doubling rate: 0.04262446393859961 doubling/hour
# Number of orders acrossing: 2.6177017201236437
#
# Time period:  202.01 hours  --- 305.99 hours
# Doubling rate: 0.004254555932790008 doubling/hour
# Number of orders acrossing: 0.1331722762369143
# [  0.   106.01 184.99]
# All phases points [  0.   106.01 184.99]
# Doubling rate: 0.07809900681559907 doubling/hour
#
#
# Doubling rate: 0.0039763640365118895 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 107.01 hours
# Doubling rate: 0.07809900681559907 doubling/hour
# Number of orders acrossing: 2.51582047552436
#
# Time period:  105.01 hours  --- 184.99 hours
# Doubling rate: 0.0039763640365118895 doubling/hour
# Number of orders acrossing: 0.09573644779659407
# [  0.    93.26 184.99]
# All phases points [  0.    93.26 184.99]
# Doubling rate: 0.08044030996227888 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 94.26 hours
# Doubling rate: 0.08044030996227888 doubling/hour
# Number of orders acrossing: 2.2825008249618675
#
# Time period:  92.26 hours  --- 184.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.   106.01 184.99]
# All phases points [  0.   106.01 184.99]
# Doubling rate: 0.06899336480474978 doubling/hour
#
#
# Doubling rate: 0.01003740125830013 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 107.01 hours
# Doubling rate: 0.06899336480474978 doubling/hour
# Number of orders acrossing: 2.2224984276809314
#
# Time period:  105.01 hours  --- 184.99 hours
# Doubling rate: 0.01003740125830013 doubling/hour
# Number of orders acrossing: 0.24166427740395147
# [  0.    69.01 136.99]
# All phases points [  0.    69.01 136.99]
# Doubling rate: 0.11583062058550304 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 70.01 hours
# Doubling rate: 0.11583062058550304 doubling/hour
# Number of orders acrossing: 2.441143069794842
#
# Time period:  68.01 hours  --- 136.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    69.01 136.99]
# All phases points [  0.    69.01 136.99]
# Doubling rate: 0.11989741053499234 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 70.01 hours
# Doubling rate: 0.11989741053499234 doubling/hour
# Number of orders acrossing: 2.526851115312728
#
# Time period:  68.01 hours  --- 136.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    69.01 136.99]
# All phases points [  0.    69.01 136.99]
# Doubling rate: 0.11571331748888829 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 70.01 hours
# Doubling rate: 0.11571331748888829 doubling/hour
# Number of orders acrossing: 2.438670894130764
#
# Time period:  68.01 hours  --- 136.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.   106.01 208.99]
# All phases points [  0.   106.01 208.99]
# Doubling rate: -0.03427404902893564 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 107.01 hours
# Doubling rate: -0.03427404902893564 doubling/hour
# Number of orders acrossing: -1.104077476039036
#
# Time period:  105.01 hours  --- 208.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.   130.76 208.99]
# All phases points [  0.   130.76 208.99]
# Doubling rate: -0.025808138732850726 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 131.76 hours
# Doubling rate: -0.025808138732850726 doubling/hour
# Number of orders acrossing: -1.0236465878578005
#
# Time period:  129.76 hours  --- 208.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    93.26 208.99]
# All phases points [  0.    93.26 208.99]
# Doubling rate: -0.013910935792149432 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 94.26 hours
# Doubling rate: -0.013910935792149432 doubling/hour
# Number of orders acrossing: -0.3947240187968206
#
# Time period:  92.26 hours  --- 208.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    45.01 208.99]
# All phases points [  0.    45.01 208.99]
# Doubling rate: -0.034230301049194035 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 46.01 hours
# Doubling rate: -0.034230301049194035 doubling/hour
# Number of orders acrossing: -0.4741030227888845
#
# Time period:  44.01 hours  --- 208.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    69.01 208.99]
# All phases points [  0.    69.01 208.99]
# Doubling rate: -0.02768860806664181 doubling/hour
#
#
# Doubling rate: 1e-06 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 70.01 hours
# Doubling rate: -0.02768860806664181 doubling/hour
# Number of orders acrossing: -0.5835404606526624
#
# Time period:  68.01 hours  --- 208.99 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
# [  0.    35.26 208.99]
# All phases points [  0.    35.26 208.99]
# Doubling rate: 1e-06 doubling/hour
#
#
# Doubling rate: -0.006396440189554582 doubling/hour
#
#
#
# Time period:  0.0 hours  --- 36.26 hours
# Doubling rate: 1e-06 doubling/hour
# Number of orders acrossing: 0.0
#
# Time period:  34.26 hours  --- 208.99 hours
# Doubling rate: -0.006396440189554582 doubling/hour
# Number of orders acrossing: -0.33644617294426116
# output file saved:./input_file_example/1_Data_fit_visualization_2021-02-10-20_12_00.pdf

# %%
file_data_frame[(file_data_frame['Condition']==40) 
& (file_data_frame['Replicate']==2)]['Cell density'].values
# Out:
# array([ 4480, 19500, 23500,  5140, 15300, 17800,  4460, 16800, 12000,
#         3030, 12700,  6890,  1530, 12200,  5850,  2110, 11500,  1390,
#         1910, 13500,  6390,  2850, 14000,  5120,  1980, 12500,  4260,
#         2110, 11600,  4660])

# %% [markdown]
# # Plotting growth rates on different dependences

# %%
pip install XlsxWriter
# Out:
# Collecting XlsxWriter
#   Downloading https://files.pythonhosted.org/packages/6b/41/bf1aae04932d1eaffee1fc5f8b38ca47bbbf07d765129539bc4bcce1ce0c/XlsxWriter-1.3.7-py2.py3-none-any.whl (144kB)
#      |████████████████████████████████| 153kB 9.8MB/s
# Installing collected packages: XlsxWriter
# Successfully installed XlsxWriter-1.3.7

# %%
import xlsxwriter

growth_rates_output_df=output_data_indices
growth_rates_output_df[
                       'Growth: Specific rate'
                       ]=growth_rates_output_df[
                                                'Growth: Doubling rate'
                                                ]*np.log(2)

growth_rates_output_df[
                       'Death: Specific rate'
                       ]=growth_rates_output_df[
                                                'Death: Doubling rate'
                                                ]*np.log(2)

growth_rates_output_units=file_data_units

for c in growth_rates_output_df.columns:
  if 'Specific' in c:
    growth_rates_output_units.loc[c, 'Unit']='1/'+time_unit
  elif 'Doubling' in c:
    growth_rates_output_units.loc[c, 'Unit']='doubling/'+time_unit
  else:
    growth_rates_output_units.loc[c, 'Unit']=' '

#growth_rates_output_df['Condition']=growth_rates_output_df['Condition'].astype(str)+' degree C'
#conditions_unique=np.sort(np.unique(growth_rates_output_df['Condition']))
#condition_dict=dict(zip(conditions_unique, range(len(conditions_unique))))

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(output_folder+'Growth_rates_table_'+dt_string+'.xlsx', 
                        engine='xlsxwriter')

# Write each dataframe to a different worksheet.
growth_rates_output_df.to_excel(writer, sheet_name='Growth rates')
growth_rates_output_units.to_excel(writer, sheet_name='Unit')
file_data_frame.to_excel(writer, sheet_name='Data')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
# %matplotlib inline
fig, ax = plt.subplots(constrained_layout=True,
                      figsize=(8,4))
ri=0
all_targets=np.unique(growth_rates_output_df['Strain'].values)

all_scatter_x=[]
all_scatter_y=[]
all_scatter_c=[]

for ri in range(len(all_targets)):
  target=all_targets[ri]
  plot_box_df=growth_rates_output_df[growth_rates_output_df['Strain']==target]

  jittering_array=[]
  for k in range(len(plot_box_df)):
    jittering_array.append(ri+0.2*(random()-0.5))

  all_scatter_x=np.r_[all_scatter_x, jittering_array]
  all_scatter_y=np.r_[all_scatter_y, plot_box_df['Growth: Specific rate'].values]
  all_scatter_c=np.r_[all_scatter_c, plot_box_df['Condition'].values]

  bp = ax.boxplot(plot_box_df['Growth: Specific rate'], 
            positions=[ri])
  
  #ax.set_xticklabels(all_targets)

  #for element in ['boxes', 'whiskers', 'means', 'medians', 'caps']:
  #            plt.setp(bp[element], color=colormap(ri))

ax.plot(range(len(all_targets)), 
        np.zeros(len(all_targets)), 'k--', alpha=0.5)

ax.set_xticklabels(all_targets)

#xticks=np.array(ax.get_xticklabels(), dtype=object)
#for ri in range(len(xticks)):
#  xticks[ri].set_color(colormap(ri))

try:
  all_scatter_c=all_scatter_c.astype(float)
  sc = ax.scatter(all_scatter_x, all_scatter_y,
                  c=all_scatter_c, alpha=0.8, cmap='coolwarm')
  cbar=fig.colorbar(sc)
except:
  print('Conditions are not numerical values.')
  conditions_unique=np.sort(np.unique(growth_rates_output_df['Condition']))
  condition_dict=dict(zip(conditions_unique, range(len(conditions_unique))))
  c_index=np.array([condition_dict[all_scatter_c[i]] 
            for i in range(len(all_scatter_c))])
  sc = ax.scatter(all_scatter_x, all_scatter_y,
                  c=c_index, alpha=0.8, cmap='jet')
  
  cbar=fig.colorbar(sc)
  cbar.ax.set_yticklabels(conditions_unique)

cbar.ax.set_ylabel(condition_unit)

secax = ax.secondary_yaxis('right', functions=(lambda x: x / np.log(2),
                                               lambda x: x * np.log(2)))

ax.set_ylabel('Specific growth rate (1/'+time_unit+')')
secax.set_ylabel('Doubling rate (doubling/'+time_unit+')')

output_file_string=output_folder+'2_Strain_growth_boxplot_'+dt_string+'.pdf'
plt.savefig(output_file_string)

print('output file saved:'+output_file_string)

plt.show()
# Out:
# output file saved:./input_file_example/2_Strain_growth_boxplot_2021-02-10-20_12_00.pdf

# %%
# For testing use
#growth_rates_output_df[
#        'Condition str']=growth_rates_output_df[
#                                    'Condition'].astype(str)+' degree C'

layer_1='Strain'
#layer_2='Condition str'
layer_2='Condition'

all_targets=np.unique(growth_rates_output_df[layer_1].values)
numerical_flag=True

# %matplotlib inline
fig, ax = plt.subplots(constrained_layout=True,
                      figsize=(8,4))

shapes=['o', '^', 's', '>', 'D', 'd', '<']


try: 
  growth_rates_output_df[
       layer_2]=growth_rates_output_df[
                                   layer_2].astype(float)

  for ri in range(len(all_targets)):
    target=all_targets[ri]
    plot_df=growth_rates_output_df[growth_rates_output_df[layer_1]==target]

    strain_df=plot_df[[layer_2, 'Growth: Specific rate']].astype(float)
    mean_GR_df=strain_df.groupby(layer_2).mean()
    min_GR_df=strain_df.groupby(layer_2).min()
    max_GR_df=strain_df.groupby(layer_2).max()

    layer_2_values=strain_df[layer_2].values
    fit_layer_2=np.arange(np.min(layer_2_values), 
                            np.max(layer_2_values), 0.01)
      
    f = interp1d(mean_GR_df.index, mean_GR_df['Growth: Specific rate'],
                  kind='quadratic')
      
    f_min = interp1d(mean_GR_df.index, min_GR_df['Growth: Specific rate'],
                  kind='quadratic')
      
    f_max = interp1d(mean_GR_df.index, max_GR_df['Growth: Specific rate'],
                  kind='quadratic')

    ax.fill_between(fit_layer_2, f_min(fit_layer_2),f_max(fit_layer_2),
            color=colormap(ri), alpha=0.1)
      
    ax.plot(fit_layer_2, f(fit_layer_2), '-',linewidth=2,
            color=colormap(ri))
      
    ax.plot(strain_df[layer_2], strain_df['Growth: Specific rate'], 
              shapes[ri], alpha=0.5, label=target)                                 
except:
  print(layer_2+' is not numerical')
  growth_rates_output_df[
        layer_2]=growth_rates_output_df[
                                    layer_2].astype(str)

  numerical_flag=False

  layer_1_array=np.unique(growth_rates_output_df[layer_1].values)
  layer_1_dict=dict(zip(layer_1_array, range(len(layer_1_array))))

  layer_2_array=np.unique(growth_rates_output_df[layer_2].values)
  layer_2_dict=dict(zip(layer_2_array, range(len(layer_2_array))))

  growth_rates_output_df[layer_1+' index']=[layer_1_dict[s] 
                                            for s in growth_rates_output_df[layer_1]]
  growth_rates_output_df[layer_2+' index']=[layer_2_dict[s] 
                                            for s in growth_rates_output_df[layer_2]]

  growth_rates_output_df['Visualization X'
  ]=growth_rates_output_df[layer_2+' index'
  ]*10+5/len(layer_1_array)*growth_rates_output_df[layer_1+' index']

  growth_rates_output_df['Visualization X jittering'
  ]=[random()-0.5 for i in range(len(growth_rates_output_df.index))]

  for j in range(len(layer_1_array)):
    s=layer_1_array[j]
    plot_df=growth_rates_output_df[growth_rates_output_df[layer_1]==s]

    for c in layer_2_array:
      plot_box_df=plot_df[plot_df[layer_2]==c]
      bp = ax.boxplot(plot_box_df['Growth: Specific rate'], 
              positions=[plot_box_df['Visualization X'].values[0]],
              widths=10/len(layer_1_array))
      for element in ['boxes', 'whiskers', 'means', 'medians', 'caps']:
        plt.setp(bp[element], color=colormap(j))

    ax.scatter(plot_df['Visualization X']+
                2/len(layer_1_array)*plot_df['Visualization X jittering'],
                plot_df['Growth: Specific rate'],s=50,
                label=s, alpha=0.5, marker=shapes[j%len(shapes)])
    
  ax.set_xticks(np.unique(plot_df['Visualization X'].values))
  ax.set_xticklabels(layer_2_array, rotation=90)                                

secax = ax.secondary_yaxis('right', functions=(lambda x: x / np.log(2),
                                               lambda x: x * np.log(2)))

secax.set_ylabel('Doubling rate (doubling/'+time_unit+')')

ax.set_ylabel('Specific growth rate (1/'+time_unit+')')
ax.set_xlabel(condition_unit)

#if numerical_flag==True:
plt.legend()

output_file_string=output_folder+'3_Condition_growth_plot_'+dt_string+'.pdf'
plt.savefig(output_file_string)

plt.show()

# %% [markdown]
# # Zip the output folder

# %%
# !zip -r $input_file_name'.zip' $input_file_name
# Out:
#   adding: input_file_example/ (stored 0%)
#   adding: input_file_example/2_Strain_growth_boxplot_2020-12-28-18_28_19.pdf (deflated 31%)
#   adding: input_file_example/3_Condition_growth_plot_2020-12-28-18_28_19.pdf (deflated 5%)
#   adding: input_file_example/1_Data_fit_visualization_2020-12-28-18_28_19.pdf (deflated 35%)
#   adding: input_file_example/Growth_rates_table_2020-12-28-18_28_19.xlsx (deflated 6%)
